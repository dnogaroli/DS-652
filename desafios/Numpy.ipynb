# %%
# !pip install scikit-image

# %% [markdown]
# ### imprimir somente 1/4 da imagem

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

img = io.imread('../images/numpy_logo.png') # Carregamento da imagem

print(type(img))

plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape)
img
RGBa - (Red, green, blue, alpha)
# Out:
# (225, 225, 4)
# array([[[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
# ...

# %%
dim = img.shape
img1 = img[:(img.shape[0]//2)][::,:img.shape[1]//2]

new_img = img[:dim[0]//2,:dim[1]//2,]


plt.imshow(img1)

# %%
size = img.shape
size
# Out:
# (225, 225, 4)

# %%
int(size[1]/2)
# Out:
# 112

# %%
new_img = img[:int(size[0]/2),:int(size[1]/2),]

# %%
plt.imshow(new_img)
